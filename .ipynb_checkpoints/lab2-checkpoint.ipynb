# %%
import matplotlib as plt
import pandas as pd
import math

# %%
data = pd.read_csv('Problem2_Dataset.csv')
data.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1702/629897471.py in ?()
#       1 data = pd.read_csv('Problem2_Dataset.csv')
# ----> 2 data.len()
#
# ~/university/maths/.venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'len'
